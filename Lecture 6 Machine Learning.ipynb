# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Supervise
# - đã có mục đích như biến y và các biến phụ thuộc x1, x2
#     - linnear regression, **note: gradient descent** (dự báo doanh thu,..)
#     - classification: email spam hay không (Bayes),..

# %%
from IPython.display import Image
Image(filename='ML_intro.png')

# %%
Image(filename='ML_intro_gradient_descent.png')

# %%
Image(filename='ML_decision_trees.png')

# %% [markdown]
# khi càng nhiều nhánh logic (độ dài cây càng dài), có thể dẫn đến overfitting khi apply trên data mới, và kết quả không như data được train (historic data)

# %% [markdown]
# ## Unsupervise: chưa có mục đích rõ ràng
# - K-mean clustering: có 1 tệp data khách hàng, đơn giản muốn phân nhỏ thành 3 tệp
# - PCA: data có quá nhiều cột (vài trăm), có những cột không cần thiết bỏ và rút gọn lượng cột có ảnh hưởng đến doanh số
# - Anomaly detection (outlier, IQR rules): cảnh báo vượt mức

# %%
Image(filename='ML_unsupervise.png')
